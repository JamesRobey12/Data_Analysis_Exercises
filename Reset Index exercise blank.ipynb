# %% [markdown]
# # Reset index practice

# %%
import pandas as pd 
import numpy as np

# %%
url = "https://www.pikminwiki.com/Piklopedia_(Pikmin_4)"

# %%
df = pd.read_html(url)

# %%
for index, i in enumerate(df):
    print(f'index = {index} {i}')
# Out:
# index = 0                                                    0
# 0  The following article or section is in need of...
# index = 1        #  Icon                   Name                      Scientific name  \
# 0      1   NaN          Dwarf Bulborb         Pansarus pseudooculii russus
# 1      2   NaN   Albino Dwarf Bulborb    Oculus kageyamii larva (1st molt)
# 2      3   NaN                Bulborb              Oculus kageyamii russus
# 3      4   NaN          Jumbo Bulborb  Oculus kageyamii russus (polyploid)
# 4      5   NaN   Dwarf Orange Bulborb       Pansarus pseudooculii orangium
# ..   ...   ...                    ...                                  ...
# 120  121   NaN           Candypop Bud                       Flora expellus
# 121  122   NaN            Pellet Posy                        Amplus nutrio
# 122  123   NaN  Burgeoning Spiderwort             Pikflora baccae conditus
# 123  124   NaN            Glow Pikmin                Pikminidae supravelum
# ...

# %%
df = df[1]

# %%
df
# Out:
#        #  Icon                   Name                      Scientific name  \
# 0      1   NaN          Dwarf Bulborb         Pansarus pseudooculii russus
# 1      2   NaN   Albino Dwarf Bulborb    Oculus kageyamii larva (1st molt)
# 2      3   NaN                Bulborb              Oculus kageyamii russus
# 3      4   NaN          Jumbo Bulborb  Oculus kageyamii russus (polyploid)
# 4      5   NaN   Dwarf Orange Bulborb       Pansarus pseudooculii orangium
# ..   ...   ...                    ...                                  ...
# 120  121   NaN           Candypop Bud                       Flora expellus
# 121  122   NaN            Pellet Posy                        Amplus nutrio
# 122  123   NaN  Burgeoning Spiderwort             Pikflora baccae conditus
# 123  124   NaN            Glow Pikmin                Pikminidae supravelum
# 124  125   NaN              Lumiknoll                     Collux aeternium
#
# ...

# %% [markdown]
# ### Question 1: Delete any number of rows using .drop.

# %%
#Interesting this is how to do a slice of indexes whe dropping

# %%
# Out:
#        #  Icon                   Name                 Scientific name  \
# 19    20   NaN          Titan Blowhog     Sus draconus (hypertrophic)
# 20    21   NaN    Blizzarding Blowhog  Sus nivisventis (hypertrophic)
# 21    22   NaN         Tusked Blowhog                   Sus magdentum
# 22    23   NaN   Armored Cannon Larva    Granitus chukkulinae (larva)
# 23    24   NaN   Horned Cannon Beetle                Granitus ferrous
# ..   ...   ...                    ...                             ...
# 120  121   NaN           Candypop Bud                  Flora expellus
# 121  122   NaN            Pellet Posy                   Amplus nutrio
# 122  123   NaN  Burgeoning Spiderwort        Pikflora baccae conditus
# 123  124   NaN            Glow Pikmin           Pikminidae supravelum
# 124  125   NaN              Lumiknoll                Collux aeternium
#
#              Family Active During Weight Max. carriers Sparklium value Seeds  \
# ...

# %% [markdown]
# ### Question 2: Reset the index in a new dataframe called df2

# %%
# Out:
#      index    #  Icon                   Name                 Scientific name  \
# 0       19   20   NaN          Titan Blowhog     Sus draconus (hypertrophic)
# 1       20   21   NaN    Blizzarding Blowhog  Sus nivisventis (hypertrophic)
# 2       21   22   NaN         Tusked Blowhog                   Sus magdentum
# 3       22   23   NaN   Armored Cannon Larva    Granitus chukkulinae (larva)
# 4       23   24   NaN   Horned Cannon Beetle                Granitus ferrous
# ..     ...  ...   ...                    ...                             ...
# 101    120  121   NaN           Candypop Bud                  Flora expellus
# 102    121  122   NaN            Pellet Posy                   Amplus nutrio
# 103    122  123   NaN  Burgeoning Spiderwort        Pikflora baccae conditus
# 104    123  124   NaN            Glow Pikmin           Pikminidae supravelum
# 105    124  125   NaN              Lumiknoll                Collux aeternium
#
# ...

# %% [markdown]
# ### Question 3: Reset the index of the original df in a new df called df3, but make sure the original index is deleted from the new dataframe

# %%
# Out:
#        #  Icon                   Name                 Scientific name  \
# 0     20   NaN          Titan Blowhog     Sus draconus (hypertrophic)
# 1     21   NaN    Blizzarding Blowhog  Sus nivisventis (hypertrophic)
# 2     22   NaN         Tusked Blowhog                   Sus magdentum
# 3     23   NaN   Armored Cannon Larva    Granitus chukkulinae (larva)
# 4     24   NaN   Horned Cannon Beetle                Granitus ferrous
# ..   ...   ...                    ...                             ...
# 101  121   NaN           Candypop Bud                  Flora expellus
# 102  122   NaN            Pellet Posy                   Amplus nutrio
# 103  123   NaN  Burgeoning Spiderwort        Pikflora baccae conditus
# 104  124   NaN            Glow Pikmin           Pikminidae supravelum
# 105  125   NaN              Lumiknoll                Collux aeternium
#
#              Family Active During Weight Max. carriers Sparklium value Seeds  \
# ...

# %% [markdown]
# ### Question 4: Edit the original dataframe by first copying  as df4, and then reseting the copy's index without putting it in a new variable.

# %%
df4 = df.copy()

# %%
# Out:
#      index    #  Icon                   Name                 Scientific name  \
# 0       19   20   NaN          Titan Blowhog     Sus draconus (hypertrophic)
# 1       20   21   NaN    Blizzarding Blowhog  Sus nivisventis (hypertrophic)
# 2       21   22   NaN         Tusked Blowhog                   Sus magdentum
# 3       22   23   NaN   Armored Cannon Larva    Granitus chukkulinae (larva)
# 4       23   24   NaN   Horned Cannon Beetle                Granitus ferrous
# ..     ...  ...   ...                    ...                             ...
# 101    120  121   NaN           Candypop Bud                  Flora expellus
# 102    121  122   NaN            Pellet Posy                   Amplus nutrio
# 103    122  123   NaN  Burgeoning Spiderwort        Pikflora baccae conditus
# 104    123  124   NaN            Glow Pikmin           Pikminidae supravelum
# 105    124  125   NaN              Lumiknoll                Collux aeternium
#
# ...

# %% [markdown]
# ### Question 5: Edit the original dataframe by first copying  as df5, then reset the copy's index without putting it in a new variable and make sure it does the original index is not stored in df5

# %%
df5 = df.copy()

# %%
# Out:
#        #  Icon                   Name                 Scientific name  \
# 0     20   NaN          Titan Blowhog     Sus draconus (hypertrophic)
# 1     21   NaN    Blizzarding Blowhog  Sus nivisventis (hypertrophic)
# 2     22   NaN         Tusked Blowhog                   Sus magdentum
# 3     23   NaN   Armored Cannon Larva    Granitus chukkulinae (larva)
# 4     24   NaN   Horned Cannon Beetle                Granitus ferrous
# ..   ...   ...                    ...                             ...
# 101  121   NaN           Candypop Bud                  Flora expellus
# 102  122   NaN            Pellet Posy                   Amplus nutrio
# 103  123   NaN  Burgeoning Spiderwort        Pikflora baccae conditus
# 104  124   NaN            Glow Pikmin           Pikminidae supravelum
# 105  125   NaN              Lumiknoll                Collux aeternium
#
#              Family Active During Weight Max. carriers Sparklium value Seeds  \
# ...
